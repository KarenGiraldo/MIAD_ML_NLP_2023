# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Taller: Análisis de sentimientos y técnicas de NLP
#
# En este taller podrán poner en práctica sus conocimientos sobre las diferentes técnicas para el procesamiento de lenguaje natural. El taller está constituido por 5 puntos, en los cuales deberan seguir las intrucciones de cada numeral para su desarrollo.

# %% [markdown]
# ## Datos predicción sentimientos de viajeros en Twitter
#
# En este taller se usará el conjunto de datos de sentimientos sobre distintas aerolíneas de EE.UU. provenientes de Twitter. Cada observación contiene si el sentimiento de los tweets es positivo, neutral o negativo teniendo en cuenta distintas variables como aerolínea y las razones de los sentimientos negativos (como "retraso en el vuelo" o "servicio grosero"). El objetivo es predecir el sentimiento asociado a cada tweet. Para más detalles pueden visitar el siguiente enlace: [datos](https://www.kaggle.com/crowdflower/twitter-airline-sentiment).

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación de librerías
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Lectura de la información de archivo .zip
tweets = pd.read_csv('https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/datasets/Tweets.zip', index_col=0)

# Visualización dataset
tweets.head()
# Out:
#                    airline_sentiment  ...               user_timezone
# tweet_id                              ...
# 570306133677760513           neutral  ...  Eastern Time (US & Canada)
# 570301130888122368          positive  ...  Pacific Time (US & Canada)
# 570301083672813571           neutral  ...  Central Time (US & Canada)
# 570301031407624196          negative  ...  Pacific Time (US & Canada)
# 570300817074462722          negative  ...  Pacific Time (US & Canada)
#
# [5 rows x 14 columns]

# %%
# Impresión tamaño del cojunto de datos
tweets.shape
# Out:
# (14640, 14)

# %% [markdown]
# ### Análisis descriptivo

# %%
# Cuenta de tweets por cada sentimiento
tweets['airline_sentiment'].value_counts()
# Out:
# airline_sentiment
# negative    9178
# neutral     3099
# positive    2363
# Name: count, dtype: int64

# %%
# Cuenta de tweets por cada aerolínea
tweets['airline'].value_counts()
# Out:
# airline
# United            3822
# US Airways        2913
# American          2759
# Southwest         2420
# Delta             2222
# Virgin America     504
# Name: count, dtype: int64

# %%
# Plot con cuenta de tweets por cada aerolínea y sentimiento
pd.crosstab(index = tweets["airline"],columns = tweets["airline_sentiment"]).plot(kind='bar',figsize=(10, 6),alpha=0.5,rot=0,stacked=True,title="Sentiminetos por aerolínea")
# Out:
# <Axes: title={'center': 'Sentiminetos por aerolínea'}, xlabel='airline'>

# %% [markdown]
# ### Liberias y Variables de interés y predicción

# %%
from sklearn.model_selection import train_test_split, cross_val_score,GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.metrics import accuracy_score
from nltk import word_tokenize,pos_tag
import nltk

# %%
# Separación de variables predictoras (X) y de variable de interés (y)
X = tweets['text']
y = tweets['airline_sentiment'].map({'negative':-1,'neutral':0,'positive':1})

# %%
# Separación de datos en set de entrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Punto 1 - Uso de CountVectorizer
#
# En la celda 1 creen un modelo de random forest con la libreria sklearn que prediga el sentimiento de los tweets usando los set de entrenamiento y test definidos anteriormente. Usen la función **CountVectorizer** y presenten el desempeño del modelo con la métrica del acurracy.
#
# Recuerden que el preprocesamiento que se haga sobre los datos de entrenamiento  (*.fit_transform()*) deben ser aplicado al set de test (*.transform()*).

# %%
# Celda 1
vec = CountVectorizer()
X_train_vec = vec.fit_transform(X_train)
X_test_vec = vec.transform(X_test)

#param_grid = {
#    'n_estimators': [100, 200, 300],
#    'max_features': ['auto', 'sqrt', 'log2'],
#    'max_depth': [None, 10, 20, 30],
#}

#modelo = GridSearchCV(estimator=RandomForestClassifier(random_state=0),
#                           param_grid=param_grid,
#                           cv=5,
#                           scoring='accuracy')

#modelo.fit(X_train_vec, y_train)
#print("Mejores parámetros:", cv_rf_model.best_params_)
#print("Mejor score de validación cruzada (accuracy):", cv_rf_model.best_score_)

modelo = RandomForestClassifier(random_state=0)
modelo.fit(X_train_vec, y_train)

y_predicc = modelo.predict(X_test_vec)
accuracy = accuracy_score(y_test, y_predicc)

print("Accuracy del modelo: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy del modelo: 77.38%

# %% [markdown]
# La precisión del modelo fue de 77.38% con la anterior, el modelo indica que tiene una buena precisión en el analisis de sentimientos de los tweets segun el texto.

# %% [markdown]
# ### Punto 2 - Eliminación de Stopwords
#
# En la celda 2 creen un modelo de random forest con la libreria sklearn que prediga el sentimiento de los tweets usando los set de entrenamiento y test definidos anteriormente. Usen la función CountVectorizer, **eliminen stopwords** y presenten el desempeño del modelo con la métrica del acurracy.
#
# Recuerden que el preprocesamiento que se haga sobre los datos de entrenamiento  (*.fit_transform()*) deben ser aplicado al set de test (*.transform()*).

# %%
# Celda 2
vec_stop = CountVectorizer(stop_words='english')

X_train_vec_stop = vec_stop.fit_transform(X_train)
X_test_vec_stop= vec_stop.transform(X_test)

modelo_2 = RandomForestClassifier(random_state=0)
modelo_2.fit(X_train_vec_stop, y_train)

y_predicc_2 = modelo_2.predict(X_test_vec_stop)
accuracy_2 = accuracy_score(y_test, y_predicc_2)

print("Accuracy del modelo después sin stopwords: {:.2f}%".format(accuracy_2 * 100))
# Out:
# Accuracy del modelo después sin stopwords: 76.18%

# %% [markdown]
# La precisión del modelo fue de 76.18% con la anterior, se puede inferir que debido a que los textos cortos como lo son los tweets pueden afectar las stopwords porque pueden tener información importante.
#
# Las palabras eliminadas fueron:

# %%
print(vec_stop.get_stop_words())
# Out:
# frozenset({'be', 'amount', 'yet', 'enough', 'four', 'herein', 'through', 'beforehand', 'again', 'per', 'first', 'become', 'which', 'mostly', 'should', 'so', 'someone', 'these', 'hasnt', 'our', 'anything', 'hundred', 'no', 'been', 'name', 'noone', 'further', 'third', 'whereas', 'every', 'seems', 'eight', 'ltd', 'what', 'and', 'formerly', 'how', 'give', 'somewhere', 'thereupon', 'himself', 'its', 'is', 'being', 'twelve', 'as', 'last', 'us', 'that', 'other', 'empty', 'whenever', 'becoming', 'too', 'but', 'all', 'might', 'ten', 'along', 'anyone', 'a', 'get', 'around', 'if', 'interest', 'their', 'sincere', 'wherever', 'you', 'they', 'put', 'also', 'never', 'across', 'system', 'either', 'became', 'now', 'rather', 'moreover', 'another', 'thick', 'thus', 'together', 'into', 'whence', 'except', 'perhaps', 'most', 'top', 'least', 'your', 'due', 'eleven', 'elsewhere', 'even', 'within', 'down', 'same', 'because', 'out', 'beyond', 'herself', 'bottom', 'everyone', 'former', 'both', 'serious', 'above', 'ourselves', 'amongst', 'his', 'was', 're', 'less', 'some', 'seemed', 'or', 'whoever', 'he', 'indeed', 'onto', 'than', 'would', 'me', 'over', 'anyhow', 'mine', 'with', 'toward', 'call', 'much', 'others', 'where', 'many', 'often', 'have', 'her', 'detail', 'them', 'part', 'amoungst', 'ie', 'my', 'could', 'any', 'nobody', 'against', 'from', 'sixty', 'cant', 'inc', 'afterwards', 'latterly', 'sometime', 'each', 'therefore', 'two', 'always', 'forty', 'until', 'on', 'namely', 'before', 'may', 'un', 'whatever', 'nevertheless', 'eg', 'yourself', 'alone', 'whereby', 'full', 'done', 'towards', 'con', 'it', 'go', 'under', 'nowhere', 'this', 'though', 'thin', 'can', 'am', 'very', 'after', 'everything', 'itself', 'do', 'side', 'still', 'the', 'thereafter', 'since', 'we', 'those', 'twenty', 'meanwhile', 'own', 'keep', 'between', 'had', 'whereafter', 'then', 'to', 'hereafter', 'fire', 'thru', 'ours', 'nine', 'nor', 'via', 'several', 'during', 'else', 'next', 'describe', 'for', 'cannot', 'found', 'wherein', 'please', 'once', 'mill', 'neither', 'one', 'she', 'couldnt', 'back', 'find', 'five', 'well', 'fill', 'behind', 'throughout', 'anyway', 'of', 'therein', 'are', 'about', 'however', 'hereupon', 'anywhere', 'whereupon', 'yours', 'made', 'move', 'see', 'him', 'were', 'cry', 'otherwise', 'must', 'take', 'whom', 'an', 'has', 'seeming', 'latter', 'more', 'themselves', 'beside', 'de', 'when', 'yourselves', 'fifty', 'whether', 'almost', 'thence', 'three', 'sometimes', 'hence', 'in', 'none', 'besides', 'why', 'only', 'somehow', 'few', 'at', 'something', 'although', 'everywhere', 'nothing', 'who', 'whose', 'whole', 'ever', 'thereby', 'up', 'here', 'already', 'bill', 'without', 'hereby', 'co', 'not', 'by', 'becomes', 'show', 'etc', 'i', 'six', 'while', 'upon', 'whither', 'myself', 'below', 'hers', 'among', 'seem', 'front', 'will', 'off', 'there', 'fifteen', 'such'})

# %% [markdown]
# ### Punto 3 - Lematización con verbos
#
# En la celda 3 creen un modelo de random forest con la libreria sklearn que prediga el sentimiento de los tweets usando los set de entrenamiento y test definidos anteriormente. Usen la función CountVectorizer, **lematizen el texto con verbos** y presenten el desempeño del modelo con la métrica del acurracy.
#
# Recuerden que el preprocesamiento que se haga sobre los datos de entrenamiento  (*.fit_transform()*) deben ser aplicado al set de test (*.transform()*).

# %%
# Celda 3
nltk.download('punkt')
nltk.download('wordnet')

lematizador = WordNetLemmatizer()

def lematizar_texto(texto):
    return [lematizador.lemmatize(word, pos='v') for word in word_tokenize(texto)]
    
vec_lemat = CountVectorizer(tokenizer=lematizar_texto)
X_train_vec_2 = vec_lemat.fit_transform(X_train)
X_test_vec_2 = vec_lemat.transform(X_test)

modelo_3 = RandomForestClassifier(random_state=0)
modelo_3.fit(X_train_vec_2, y_train)

y_predicc_3 = modelo_3.predict(X_test_vec_2)
accuracy_3 = accuracy_score(y_test, y_predicc_3)

print("Precisión del modelo con lematización de verbos: {:.2f}%".format(accuracy_3 * 100))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\carit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\carit\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Precisión del modelo con lematización de verbos: 77.65%

# %% [markdown]
# Se mantiene no la precisión del modelo con la lematización con uan precisión de 77.65%

# %% [markdown]
# ### Punto 4 - Multiples técnicas
#
# En la celda 4 creen un modelo de random forest con la libreria sklearn que prediga el sentimiento de los tweets usando los set de entrenamiento y test definidos anteriormente. Usen la función **CountVectorizer, eliminen stopwords, lematizen el texto con verbos** y presenten el desempeño del modelo con la métrica del acurracy.
#
# Recuerden que el preprocesamiento que se haga sobre los datos de entrenamiento  (*.fit_transform()*) deben ser aplicado al set de test (*.transform()*).

# %%
# Celda 4
nltk.download('averaged_perceptron_tagger')

lematizador = WordNetLemmatizer()

#def lematizar_verbos(texto):
#    tokens = word_tokenize(texto)
#    return [lematizador.lemmatize(word, 'v') if pos.startswith('V') else word for word, pos in pos_tag(tokens)]
def lematizar_verbos(texto):
    tokens = word_tokenize(texto)
    palabras_eliminadas = []
    tokens_finales = []
    for word, pos in pos_tag(tokens):
        if word.lower() in stop_words:
            palabras_eliminadas.append(word)
        else:
            lematizado = lematizador.lemmatize(word, 'v') if pos.startswith('V') else word
            tokens_finales.append(lematizado)
    #print(f"Palabras eliminadas: {palabras_eliminadas}")  
    return tokens_finales
    
vect_lemat_2 = CountVectorizer(tokenizer=lematizar_verbos, stop_words='english')
X_train_vec_3 = vect_lemat_2.fit_transform(X_train)
X_test_vec_3 = vect_lemat_2.transform(X_test)

modelo_4 = RandomForestClassifier(random_state=0)
modelo_4.fit(X_train_vec_3, y_train)

y_predicc_4 = modelo_4.predict(X_test_vec_3)
accuracy_4 = accuracy_score(y_test, y_predicc_4)

print("Precisión del modelo con multiples técnicas: {:.2f}%".format(accuracy_4 * 100))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\carit\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Palabras eliminadas: ['be']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['through']
# Palabras eliminadas: []
# Palabras eliminadas: ['again']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['which']
# Palabras eliminadas: []
# Palabras eliminadas: ['should']
# Palabras eliminadas: ['so']
# Palabras eliminadas: []
# Palabras eliminadas: ['these']
# Palabras eliminadas: []
# Palabras eliminadas: ['our']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['no']
# Palabras eliminadas: ['been']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['further']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['what']
# Palabras eliminadas: ['and']
# Palabras eliminadas: []
# Palabras eliminadas: ['how']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['himself']
# Palabras eliminadas: ['its']
# Palabras eliminadas: ['is']
# Palabras eliminadas: ['being']
# Palabras eliminadas: []
# Palabras eliminadas: ['as']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['that']
# Palabras eliminadas: ['other']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['too']
# Palabras eliminadas: ['but']
# Palabras eliminadas: ['all']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['a']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['if']
# Palabras eliminadas: []
# Palabras eliminadas: ['their']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['you']
# Palabras eliminadas: ['they']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['now']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['into']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['most']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['your']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['down']
# Palabras eliminadas: ['same']
# Palabras eliminadas: ['because']
# Palabras eliminadas: ['out']
# Palabras eliminadas: []
# Palabras eliminadas: ['herself']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['both']
# Palabras eliminadas: []
# Palabras eliminadas: ['above']
# Palabras eliminadas: ['ourselves']
# Palabras eliminadas: []
# Palabras eliminadas: ['his']
# Palabras eliminadas: ['was']
# Palabras eliminadas: ['re']
# Palabras eliminadas: []
# Palabras eliminadas: ['some']
# Palabras eliminadas: []
# Palabras eliminadas: ['or']
# Palabras eliminadas: []
# Palabras eliminadas: ['he']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['than']
# Palabras eliminadas: []
# Palabras eliminadas: ['me']
# Palabras eliminadas: ['over']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['with']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['where']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['have']
# Palabras eliminadas: ['her']
# Palabras eliminadas: []
# Palabras eliminadas: ['them']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['my']
# Palabras eliminadas: []
# Palabras eliminadas: ['any']
# Palabras eliminadas: []
# Palabras eliminadas: ['against']
# Palabras eliminadas: ['from']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['each']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['until']
# Palabras eliminadas: ['on']
# Palabras eliminadas: []
# Palabras eliminadas: ['before']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['yourself']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['it']
# Palabras eliminadas: []
# Palabras eliminadas: ['under']
# Palabras eliminadas: []
# Palabras eliminadas: ['this']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['can']
# Palabras eliminadas: ['am']
# Palabras eliminadas: ['very']
# Palabras eliminadas: ['after']
# Palabras eliminadas: []
# Palabras eliminadas: ['itself']
# Palabras eliminadas: ['do']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['the']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['we']
# Palabras eliminadas: ['those']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['own']
# Palabras eliminadas: []
# Palabras eliminadas: ['between']
# Palabras eliminadas: ['had']
# Palabras eliminadas: []
# Palabras eliminadas: ['then']
# Palabras eliminadas: ['to']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['ours']
# Palabras eliminadas: []
# Palabras eliminadas: ['nor']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['during']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['for']
# Palabras eliminadas: ['can', 'not']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['once']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['she']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['of']
# Palabras eliminadas: []
# Palabras eliminadas: ['are']
# Palabras eliminadas: ['about']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['yours']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['him']
# Palabras eliminadas: ['were']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['whom']
# Palabras eliminadas: ['an']
# Palabras eliminadas: ['has']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['more']
# Palabras eliminadas: ['themselves']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['when']
# Palabras eliminadas: ['yourselves']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['in']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['why']
# Palabras eliminadas: ['only']
# Palabras eliminadas: []
# Palabras eliminadas: ['few']
# Palabras eliminadas: ['at']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['who']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['up']
# Palabras eliminadas: ['here']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['not']
# Palabras eliminadas: ['by']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['i']
# Palabras eliminadas: []
# Palabras eliminadas: ['while']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['myself']
# Palabras eliminadas: ['below']
# Palabras eliminadas: ['hers']
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: []
# Palabras eliminadas: ['will']
# Palabras eliminadas: ['off']
# Palabras eliminadas: ['there']
# Palabras eliminadas: []
# Palabras eliminadas: ['such']
# Palabras eliminadas: ['of', 'i', 'am']
# Palabras eliminadas: ['on', 'from', 'a', 'that', 'no', 'and', 'not', 'what', 'i', 'from']
# Palabras eliminadas: ['to']
# Palabras eliminadas: ['does', 'from', 'your', 'how', 'to', 'do', 'their']
# Palabras eliminadas: ['i', 'a']
# Palabras eliminadas: ['my', 'to', 'from', 'has', 'been', 'no', 'has', 'me', 'what', 'on']
# Palabras eliminadas: ['no', 'it', 'is', 'i', 'to', 'but', 'it', 'is', 'too', 'i', 'did', 'not', 'an', 'that', 'i']
# Palabras eliminadas: ['i', 'to', 'to', 'you']
# Palabras eliminadas: ['you', 'have', 'the', 'to', 'my', 'to', 'but', 'you', 'can', 'not', 'me', 'where', 'my', 'are']
# Palabras eliminadas: ['with', 'she', 'should', 'not', 'be']
# Palabras eliminadas: ['you', 'you', 'too']
# Palabras eliminadas: ['or', 'my', 'here', 'is', 'on', 'now', 'have', 'the']
# Palabras eliminadas: ['to', 'on', 'i', 'i', 'will', 'that', 'you', 'just']
# Palabras eliminadas: ['was', 'just', 'up', 'on', 'by', 'after', 'on', 'that', 'not', 'was']
# Palabras eliminadas: ['my', 'in', 'no']
# Palabras eliminadas: ['as', 'i', 'have', 'a', 'that', 'i', 'a', 'a', 'of']
# Palabras eliminadas: ['why', 'are', 'the', 'in', 'so', 'of', 'the']
# Palabras eliminadas: ['why', 'you', 'a', 'who', 'does', 'about', 'the', 'of', 'not']
# Palabras eliminadas: ['my', 'are', 'that', 'they', 'are', 'more', 'of', 'from', 'than']
# Palabras eliminadas: ['when', 'you', 'in', 'a', 'you', 'to', 'your', 'but', 'not']
# Palabras eliminadas: ['as', 'a', 'no', 'was', 'to', 'those', 'i', 'out']
# Palabras eliminadas: ['can', 'i', 'in', 'my', 'on', 'now', 'be', 'a', 'so', 'the', 'can', 'you', 'some']
# Palabras eliminadas: ['i', 'the', 'me']
# Palabras eliminadas: ['the', 'is', 'itself', 'i', 'that', 'is', 'your', 'but', 'your', 'to', 'it', 'have', 'been']
# Palabras eliminadas: ['how', 'about', 'you', 'a', 'to', 'of', 'the', 'you', 'are', 'not', 'on', 'it']
# Palabras eliminadas: ['i', 'been', 'to', 'through', 'to', 'a', 'and', 'the', 'will', 'not', 'me', 'through']
# Palabras eliminadas: ['our', 'on', 'no']
# Palabras eliminadas: ['that']
# Palabras eliminadas: []
# Palabras eliminadas: ['that', 'you', 'just', 'to', 'a', 'of', 'so', 'we', 'with', 'the', 'after', 'he']
# Palabras eliminadas: ['to', 'being', 'to', 'me', 'for', 'not']
# Palabras eliminadas: []
# Palabras eliminadas: ['i', 'the', 'and', 'when', 'i', 'to', 'to', 'his', 'i', 'was', 'no']
# Palabras eliminadas: ['i', 'my', 'then', 'i', 'the', 'they', 'me', 'on', 'now', 'i', 'to', 'of']
# Palabras eliminadas: ['for', 'my', 'own', 'just', 'to', 'not', 'through', 'this', 'for', 'the']
# Palabras eliminadas: ['to', 'in', 'my', 'on', 'from', 'to', 'not', 'me']
# Palabras eliminadas: ['now', 'no', 'i', 'not', 'why', 'do', 'you', 'have', 'a', 'or', 'to', 'the', 'not']
# Palabras eliminadas: ['you']
# Palabras eliminadas: ['it', 'with', 'my', 'but', 'you', 'should', 'it', 'just', 'most', 'of', 'the', 'through', 'then']
# Palabras eliminadas: ['at', 'from', 'i', 'have', 'is', 'have', 'to']
# Palabras eliminadas: ['only', 'an', 'but', 'of', 'the', 'i', 'had', 'to', 'and', 'in']
# Palabras eliminadas: ['is', 'on', 'not']
# Palabras eliminadas: ['me', 'my', 'for', 'my']
# Palabras eliminadas: ['and', 'i', 'am', 'what', 'to', 'had', 'to']
# Palabras eliminadas: ['when', 'i', 'to', 'the', 'i', 'if', 'there', 'where', 'any', 'other', 'very', 'to', 'the']
# Palabras eliminadas: ['no', 'but', 'my', 'in', 'the', 'did', 'and', 'he', 'it', 'was']
# Palabras eliminadas: ['to', 'the']
# Palabras eliminadas: ['i', 'be', 'but', 'it', 'on', 'the', 'is', 'not', 'a']
# Palabras eliminadas: ['to', 'a', 'and', 'the', 'is', 'not', 'a', 'to']
# Palabras eliminadas: ['to', 'and', 'if', 'they', 'will', 'the']
# Palabras eliminadas: ['very', 'with', 'the', 'of', 'from', 'your', 'i', 'had', 'to', 'just', 'for', 'a']
# Palabras eliminadas: ['now', 'after', 'and', 'in', 'who', 'do', 'i']
# Palabras eliminadas: ['i', 'to', 'the', 'it', 'be', 'to', 'their', 'for']
# Palabras eliminadas: ['we', 'did', 'it', 'about', 'to', 'our', 'so', 'to', 'on', 'our', 'being', 'on', 'the', 'in']
# Palabras eliminadas: ['here', 'was', 'at', 'my', 'did', 'in', 'of', 'me', 'to', 'my']
# Palabras eliminadas: []
# Palabras eliminadas: ['on', 'the', 'at', 'i', 'was', 'on', 'out', 'of', 'here', 'and', 'that', 'was', 'only']
# Palabras eliminadas: ['on', 'for', 'the', 'so']
# Palabras eliminadas: ['and']
# Palabras eliminadas: ['you', 'for', 'so', 'with', 'a']
# Palabras eliminadas: ['for', 'that', 'in', 'your', 'should', 'be', 'a']
# Palabras eliminadas: ['on', 'the', 'at', 'and', 'now', 'in', 'and', 'no']
# Palabras eliminadas: ['i', 'to', 'for', 'and', 'a', 'can', 'you', 'the']
# Palabras eliminadas: ['no', 'out', 'of', 'are', 'you', 'me', 'why', 'are', 'other', 'and', 'you', 'not', 'so']
# Palabras eliminadas: ['does', 'have', 'to', 'be', 'same', 'and', 'will']
# Palabras eliminadas: ['on', 'in', 'no', 'very', 'and']
# Palabras eliminadas: ['what', 'is', 'out']
# Palabras eliminadas: []
# Palabras eliminadas: ['the', 'is', 'not', 'here', 'it', 'it', 'to', 'before', 'me', 'not', 'your']
# Palabras eliminadas: []
# Palabras eliminadas: ['my', 'from', 'in', 'her', 'her']
# Palabras eliminadas: ['the', 'to', 'and', 'on', 'to', 'same']
# Palabras eliminadas: ['why', 'did', 'you', 'my', 'on', 'the', 'after', 'then', 'not', 'it', 'to', 'me', 'you', 'now', 'the', 'as']
# Palabras eliminadas: ['what', 'the', 'why', 'a', 'only', 'to', 'it', 'on']
# Palabras eliminadas: ['is', 'my']
# Palabras eliminadas: ['why', 'i', 'a', 'from', 'to', 'the', 'up', 'for']
# Palabras eliminadas: ['and', 'when', 'did', 'your', 'your']
# Palabras eliminadas: ['is', 'a', 'my']
# Palabras eliminadas: ['are', 'you', 'this', 'is', 'you', 'these', 'they', 'for', 'the']
# Palabras eliminadas: ['or']
# Palabras eliminadas: ['to', 'and']
# Palabras eliminadas: ['if', 'it', 'your']
# Palabras eliminadas: ['this', 'is']
# Palabras eliminadas: ['to', 'any', 'how', 'that', 'again', 'to']
# Palabras eliminadas: ['i', 'that', 'my', 'and', 'i', 'will', 'be', 'as', 'of']
# Palabras eliminadas: ['over', 'the', 'during', 'the', 'i', 'was', 'on', 'the', 'for', 'with', 'no']
# Palabras eliminadas: ['have', 'to', 'but', 'not']
# Palabras eliminadas: ['i', 'do', 'you', 'should', 'him', 'at', 'all', 'on', 'his', 'the', 'and']
# Palabras eliminadas: ['you', 'so', 'that', 'a', 'is', 'on', 'this', 'a', 'and', 'a']
# Palabras eliminadas: ['for', 'the', 'on', 'a', 'the', 'the']
# Palabras eliminadas: ['it', 'to', 'you', 'you', 'so']
# Palabras eliminadas: ['i', 'a', 'and', 'have', 'not', 'a', 'to', 'to']
# Palabras eliminadas: ['i', 'was', 'of', 'by', 'this', 'i', 'am', 'my']
# Palabras eliminadas: ['but', 'not', 'being', 'to', 'through', 'to', 'a', 'for', 'over', 'is', 'just']
# Palabras eliminadas: ['will', 'this']
# Palabras eliminadas: ['and', 'i', 'of', 'is', 'there', 'any', 'other']
# Palabras eliminadas: ['some', 'on', 'and', 'in', 'the', 'for', 'her', 'with', 'i']
# Palabras eliminadas: ['no', 'i', 'to', 'this', 'of', 'again', 'i', 'some', 'of']
# Palabras eliminadas: ['who', 'can', 'i', 'about', 'a']
# Palabras eliminadas: ['you', 'have', 'me', 'down']
# Palabras eliminadas: ['if', 'on', 'through', 'on', 'to', 'because', 'he', 'couldn', 't', 'on', 'i', 'will', 'you', 'for']
# Palabras eliminadas: ['i', 'do', 'but', 'it', 'to']
# Palabras eliminadas: ['you', 'for', 'your', 'there', 'is', 'more', 'to', 'this', 'than', 'just', 'the', 'but', 'you', 'for', 'out']
# Palabras eliminadas: ['for', 'you', 'to', 'up', 'up', 'on', 'now']
# Palabras eliminadas: ['i', 'to', 'to', 'with', 'the', 'to', 'do', 'there']
# Palabras eliminadas: ['been', 'on', 'my', 'was', 'but', 'my', 'is', 'on']
# Palabras eliminadas: ['or']
# Palabras eliminadas: ['my', 'for', 'then', 'on', 'the', 'i', 'here', 'with', 'a', 'no']
# Palabras eliminadas: ['with', 'no', 'to']
# Palabras eliminadas: ['with', 'and', 'do', 'they', 'to', 'in', 'at']
# Palabras eliminadas: ['it']
# Palabras eliminadas: ['a', 'a']
# Palabras eliminadas: ['and', 'this', 'on', 'a', 'and', 'are', 'of', 'a']
# Palabras eliminadas: ['over', 'an', 'not', 'a', 'on', 'the', 'you', 'so', 'now']
# Palabras eliminadas: ['is', 'up', 'their']
# Palabras eliminadas: ['i', 'it', 'not', 'not', 'why']
# Palabras eliminadas: ['about', 'your', 'in', 'my', 'up', 'the']
# Palabras eliminadas: ['up', 'our', 'they', 'a', 'to', 'just', 'of', 'when', 'they', 'our', 'only', 'the']
# Palabras eliminadas: ['their', 'as', 'no', 'to', 'more', 'now', 'we', 'not', 'from', 'for']
# Palabras eliminadas: ['too', 'with', 'are', 'they', 'or', 'is', 'it', 'a']
# Palabras eliminadas: ['that', 'me', 'so', 'but', 'then', 'i', 'the', 'and', 'that', 'was', 'and', 'me', 'where', 'the', 'was']
# Palabras eliminadas: ['i', 'just', 'it', 'to', 'have', 'as']
# Palabras eliminadas: ['will', 'do']
# Palabras eliminadas: ['so', 'i', 'to', 'the', 'so', 'i', 'can', 'with', 'but', 'them', 'only', 'on']
# Palabras eliminadas: ['most', 'on', 'off', 'been', 'in', 'for', 'now', 'to']
# Palabras eliminadas: ['just', 'an', 'at', 'she', 'no']
# Palabras eliminadas: ['can', 'you', 'my', 'too']
# Palabras eliminadas: ['and', 'then', 'when', 'we', 'the', 'to', 'the', 'as', 'she', 'not', 'with', 'my']
# Palabras eliminadas: ['to', 'this']
# Palabras eliminadas: ['we', 'been', 'on', 'for', 'over', 'you']
# Palabras eliminadas: ['is', 'from', 'to', 'now', 'that', 'is', 'most']
# Palabras eliminadas: ['i', 'in', 'i', 'to', 'to', 'my', 'on', 'is']
# Palabras eliminadas: ['you', 'so', 'its', 'been', 'a', 'very']
# Palabras eliminadas: ['your', 'out', 'of', 'me', 'my', 'out', 'of', 'out', 'how', 'to', 'off', 'and', 'on']
# Palabras eliminadas: ['i', 'did', 'through', 'these', 'after', 'my', 'i', 'how', 'are']
# Palabras eliminadas: ['i']
# Palabras eliminadas: ['what', 'is', 'the', 'with', 'when', 'is', 'it', 'why', 'is', 'it', 'so']
# Palabras eliminadas: ['but', 'i', 'will', 'i', 'my', 'of', 'a', 'on', 'my', 'they', 'him', 'in', 'a']
# Palabras eliminadas: ['no', 'been', 'here', 'on']
# Palabras eliminadas: ['is', 'the']
# Palabras eliminadas: ['on', 'of', 'the', 'no', 'i', 'am', 'now', 'to', 'a', 'to', 'your', 'of']
# Palabras eliminadas: ['in', 'with', 'no', 'is', 'no']
# Palabras eliminadas: ['not', 'with', 'the', 'is', 'under', 'what', 'up']
# Palabras eliminadas: ['do', 'you', 'have', 'a']
# Palabras eliminadas: ['how', 'it', 'is', 'not', 'to', 'on', 'the', 'you', 'me', 'on', 'for', 'an', 'and', 'then', 'me', 'off']
# Palabras eliminadas: ['not', 'to', 'an', 'why', 'no', 'to', 'you', 'be', 'on', 'for', 'then']
# Palabras eliminadas: ['into', 'and', 'for', 'at']
# Palabras eliminadas: ['i', 'be', 'of', 'the', 'this', 'should', 'be']
# Palabras eliminadas: ['you', 'of', 'with', 'this']
# Palabras eliminadas: ['i', 'very', 'your', 'can', 'you', 'me', 'it', 'an']
# Palabras eliminadas: ['i', 'was', 'on', 'and', 'my', 'in', 'me', 'them']
# Palabras eliminadas: ['by', 'was', 'as', 'and', 'a', 'i', 'be']
# Palabras eliminadas: []
# Palabras eliminadas: ['i', 'been', 'on', 'how', 'do', 'you', 'have']
# Palabras eliminadas: ['you', 'your', 'to', 'have', 'some', 'and']
# Palabras eliminadas: ['how', 'about', 'me', 'with', 'a', 'i', 'to', 'a', 'than', 'a']
# Palabras eliminadas: ['i', 'a', 'for', 'for', 'a', 'from', 'the']
# Palabras eliminadas: []
# Palabras eliminadas: ['you', 'very', 'this', 'is', 'why', 'you', 'my']
# Palabras eliminadas: ['this']
# Palabras eliminadas: ['to', 'all', 'the', 'you', 'have', 'to']
# Palabras eliminadas: ['we', 'are', 'we', 'are', 'at', 'for', 'about']
# Palabras eliminadas: ['for', 'then']
# Palabras eliminadas: ['on', 'to', 'now', 'i', 'was', 'in', 'as', 'my', 'is', 'under', 'her', 'too']
# Palabras eliminadas: ['me', 'on', 'my', 'to', 'a']
# Palabras eliminadas: ['no', 'my', 'were', 'not']
# Palabras eliminadas: ['so', 'no', 'as', 'to', 'why', 'this', 'is', 'is', 'there', 'i', 'should', 'or', 'me', 'to', 'a']
# Palabras eliminadas: ['we', 'out', 'through', 'and', 'into', 'when', 'we', 'with', 'or']
# Palabras eliminadas: ['at', 'with', 'for', 'no', 'to']
# Palabras eliminadas: ['on', 'a']
# Palabras eliminadas: ['on', 'a']
# Palabras eliminadas: ['what', 'does', 'do', 'on', 'with', 'than', 'are']
# Palabras eliminadas: ['at', 'you', 'on', 'she', 'is']
# Palabras eliminadas: ['in', 'by', 'for', 'to', 'how', 'does', 'that']
# Palabras eliminadas: ['for', 'the', 'and', 'then', 'no', 'when', 'we', 'at', 'you', 'did', 'my']
# Palabras eliminadas: ['if', 'a', 'to', 'on', 'then', 'in', 'an', 'they', 'to', 'in']
# Palabras eliminadas: ['my', 'when', 'the', 'out']
# Palabras eliminadas: ['i', 'you', 'are', 'to', 'my', 'to', 'for', 'be', 'to', 'have', 'some', 'for']
# Palabras eliminadas: ['is', 'my', 'from', 'to']
# Palabras eliminadas: ['and', 'they', 'in', 'a', 'until', 'they', 'off', 'then', 'more', 'to', 'their']
# Palabras eliminadas: ['how', 'do', 'you', 'have', 'only', 'into', 'this', 'with', 'the', 'a']
# Palabras eliminadas: ['now']
# Palabras eliminadas: ['i', 'can', 'that', 'i', 'just', 'had', 'so', 'in', 'the', 'with']
# Palabras eliminadas: ['you', 'to', 'to', 'on', 'you', 'now', 'and']
# Palabras eliminadas: ['is', 'a', 'of', 'at', 'this', 'am']
# Palabras eliminadas: ['to', 'for', 'at', 'the', 'we', 'were', 'that', 'our', 'did', 'through', 'was', 'i']
# Palabras eliminadas: ['i', 'we', 'are', 'all', 'at', 'a', 'at', 'and', 'it', 'are']
# Palabras eliminadas: ['they', 'were', 'and', 'you']
# Palabras eliminadas: ['was', 'than', 'what', 'was', 'from']
# Palabras eliminadas: ['why', 'i', 'to', 'because', 'a', 'in', 'being']
# Palabras eliminadas: ['i', 'with', 'in', 'the', 'can', 'we', 'on', 'those']
# Palabras eliminadas: ['been', 'on', 'with', 'for', 'over']
# Palabras eliminadas: ['you', 'have', 'me', 'down']
# Palabras eliminadas: ['i', 'you', 'an', 'no']
# Palabras eliminadas: ['i', 'it', 'i', 'to', 'on', 'their', 'to', 'and', 'they', 'on', 'that']
# Palabras eliminadas: ['who', 'do', 'you', 'is', 'or']
# Palabras eliminadas: ['is', 'there', 'any', 'to', 'to', 'the', 'to']
# Palabras eliminadas: ['you', 'for', 'this', 'to', 'our', 'we', 'be', 'to', 'out', 'to', 'so', 'we', 'can', 'this']
# Palabras eliminadas: ['they', 'just', 'by']
# Palabras eliminadas: ['we', 'have', 'been', 'on', 'the', 'and', 'is', 'we', 'can', 'them']
# Palabras eliminadas: ['i', 'but', 'is', 'can', 'you']
# Palabras eliminadas: ['for', 'my', 'she', 'a', 'from', 'your', 'she', 'was', 'a', 'for']
# Palabras eliminadas: ['not', 'a', 'on', 'my', 'before', 'and', 'the', 'me', 'a']
# Palabras eliminadas: ['we', 'can', 'because', 'we', 'that', 'had', 'to', 'and', 'we', 'do', 'them']
# Palabras eliminadas: ['if', 'a', 'is', 'that', 'and', 'is', 'it', 'a']
# Palabras eliminadas: ['has', 'the', 'of', 'any', 'i']
# Palabras eliminadas: ['i', 'to', 'have', 'a', 'once', 'i', 'it']
# Palabras eliminadas: ['i', 'a', 'how', 'do', 'i', 'from', 'to', 'in', 'the', 'to', 'to', 'other', 'and']
# Palabras eliminadas: ['how', 'about', 'some', 'at', 'to', 'be', 'in']
# Palabras eliminadas: ['or', 'you', 'me', 'a']
# Palabras eliminadas: ['i', 'were', 'down', 'for', 'my', 'is']
# Palabras eliminadas: ['from', 'to', 'then', 'from', 'to', 'to', 'were']
# Palabras eliminadas: []
# Palabras eliminadas: ['you', 'this', 'it', 'does', 'to', 'to', 'an']
# Palabras eliminadas: ['why', 'am', 'i', 'on', 'by', 'when', 'your']
# Palabras eliminadas: ['we', 'and', 'we', 'have', 'to', 'a', 'to', 'our', 'at', 'these', 'should', 'have']
# Palabras eliminadas: ['i', 'have', 'had', 'the', 'has', 'been']
# Palabras eliminadas: ['but', 'we', 'you', 'there']
# Palabras eliminadas: ['my', 'is']
# Palabras eliminadas: ['on', 'my', 'from', 'to', 'just', 'after']
# Palabras eliminadas: ['to', 'at', 'in', 'for', 'her', 'on', 'to', 'of', 'when', 'other', 'were']
# Palabras eliminadas: ['is', 'this', 'a', 'my', 'is', 'too', 'in', 'a', 'from', 'you']
# Palabras eliminadas: ['i', 'been', 'on', 'the', 'and', 'now', 'has', 'a', 'of', 'more', 'than']
# Palabras eliminadas: ['i', 'do', 'not', 'to', 'for', 'a', 'when', 'i', 'have', 'to', 'for', 'a']
# Palabras eliminadas: ['i', 'will', 'if', 'you', 'can', 'about', 'up', 'my', 'in', 'to', 'the']
# Palabras eliminadas: ['i', 'you']
# Palabras eliminadas: ['i', 'a', 'of', 'what', 'the', 'on', 'my']
# Palabras eliminadas: ['will', 'you', 'be']
# Palabras eliminadas: ['just', 'so', 'you', 'has', 'a']
# Palabras eliminadas: ['i', 'will', 'you', 'have', 'to', 'that', 'for', 'is', 'i', 'only', 'and', 'my', 'is', 'here']
# Palabras eliminadas: ['what', 'about']
# Palabras eliminadas: []
# Palabras eliminadas: ['you', 'again', 'all', 'i', 'to', 'do', 'is', 'my', 'for', 'a', 'but', 'i', 'do', 'it']
# Palabras eliminadas: ['it', 'been', 'and', 'no', 'from', 'on', 'of', 'to', 'any', 'on', 'your']
# Palabras eliminadas: ['been', 'on', 'for', 'more', 'than', 'an']
# Palabras eliminadas: ['from', 'to']
# Palabras eliminadas: ['with', 'no', 'after']
# Palabras eliminadas: ['why', 'they', 'me', 'a']
# Palabras eliminadas: ['how', 'about', 'an', 'this', 'up']
# Palabras eliminadas: ['it', 'to', 'out', 'is', 'on', 'the', 'than', 'in', 'the']
# Palabras eliminadas: ['do', 'you', 'not', 'to', 'to', 'their', 'no', 'to', 'on', 'if', 'you', 'had', 'no', 'for']
# Palabras eliminadas: ['to', 'is', 'than']
# Palabras eliminadas: ['can', 'the', 'on', 'on']
# Palabras eliminadas: ['i', 'was', 'just', 'very', 'it', 'over', 'that', 'on']
# Palabras eliminadas: ['down', 'no', 'it']
# Palabras eliminadas: ['and', 'now', 'your', 'has', 'to', 'an', 'of', 'our', 'in', 'for']
# Palabras eliminadas: ['of', 'and', 'i', 'the', 'for', 'all', 'my']
# Palabras eliminadas: ['me', 'up']
# Palabras eliminadas: ['i', 'do', 'why', 'i', 'my', 'i', 'was', 'on', 'the', 'it', 'was', 'in', 'my']
# Palabras eliminadas: ['over', 'an', 'on', 'so']
# Palabras eliminadas: ['i', 'you', 'are', 'we', 'were', 'of', 'the', 'out', 'of', 'just', 'more']
# Palabras eliminadas: ['to', 'and']
# Palabras eliminadas: ['i', 'can', 'not', 'how', 'is', 'i', 'it', 'but', 'you', 'own', 'it', 'i', 'to']
# Palabras eliminadas: ['i', 'did', 'for', 'the', 'i', 'before', 'as', 'for', 'the']
# Palabras eliminadas: ['if', 'you', 'for', 'on', 'a', 'as', 'as', 'they', 'can', 'you', 'should', 'what', 'you', 'that']
# Palabras eliminadas: ['so', 'i', 'after', 'to', 'at', 'the', 'about', 'my', 'than', 'yours']
# Palabras eliminadas: ['and', 'of', 'i', 'have', 'to', 'in', 'more', 'on', 'than', 'my']
# Palabras eliminadas: ['for', 'the', 'i', 'a', 'in', 'how', 'can', 'i', 'that', 'again']
# Palabras eliminadas: ['what', 'for', 'does', 'in']
# Palabras eliminadas: ['there', 'me', 'again', 'from', 'on']
# Palabras eliminadas: ['had', 'a', 'this', 'to', 'for', 'and', 'had', 'this', 'over', 'the', 'on']
# Palabras eliminadas: ['on', 'will', 'we', 'be', 'or']
# Palabras eliminadas: ['this', 'have', 'a', 'this']
# Palabras eliminadas: ['why', 'am', 'i', 'not', 'being', 'a', 'why', 'has', 'this', 'been', 'off']
# Palabras eliminadas: ['the', 'a']
# Palabras eliminadas: ['he', 'to', 'and', 'on']
# Palabras eliminadas: ['on', 'the', 'again', 'on', 'not', 'a', 'to', 'of', 'your']
# Palabras eliminadas: ['has', 'the', 'through', 'to', 'a', 'you', 'be', 'me']
# Palabras eliminadas: ['you', 'so', 'i', 'was', 'in', 'the', 'is', 'to', 'with']
# Palabras eliminadas: ['i', 'just', 'to', 'be', 'and', 'to', 'the', 'on', 'my']
# Palabras eliminadas: ['you']
# Palabras eliminadas: ['on', 'that', 'with', 'a', 'and', 'we', 'you', 'are']
# Palabras eliminadas: ['and', 'i', 'have', 'to', 'for', 'at', 'same', 'for']
# Palabras eliminadas: ['i', 'been', 'on', 'for', 'over', 'there', 'has', 'to', 'be', 'an', 'to', 'a']
# Palabras eliminadas: ['you']
# Palabras eliminadas: ['it', 'was', 'now', 'i', 'in', 'because', 'i', 'my', 'because', 'of', 'the']
# Palabras eliminadas: ['has', 'been', 'out', 'too', 'we', 'they', 'up', 'is', 'our']
# Palabras eliminadas: ['our', 'just', 'at', 'the', 'so', 'they', 'the']
# Palabras eliminadas: ['had', 'my', 'to', 'was', 'but', 'is', 'me', 'to', 'the', 'again']
# Palabras eliminadas: ['i', 'up', 'on', 'so', 'i', 'can', 'a', 'with', 'you', 'i', 'be', 'to', 'i', 'to']
# Palabras eliminadas: ['what', 'did', 'you', 'do', 'with', 'my']
# Palabras eliminadas: ['for', 'my', 'it', 'to', 'my', 'and', 'not', 'the']
# Palabras eliminadas: ['a', 'on', 'now', 'me', 'a', 'on', 'an']
# Palabras eliminadas: ['how', 'does', 'that']
# Palabras eliminadas: ['that', 'the', 'my', 'was', 'after', 'all', 'and', 'i', 'be', 'there', 'by', 'not']
# Palabras eliminadas: ['to', 'with']
# Palabras eliminadas: ['how', 'does', 'your', 'who', 'does', 'to', 'their', 'can', 'a']
# Palabras eliminadas: ['no', 'for', 'from', 'or', 'if', 'a', 'do', 'have', 'i', 'can', 'to']
# Palabras eliminadas: ['they', 'an', 'of', 'and', 'to', 'i', 'have', 'my', 'and', 'and', 'they', 'have', 'no']
# Palabras eliminadas: ['for', 'the', 'the', 'be', 'so']
# Palabras eliminadas: ['out', 'to', 'the', 'for', 'from', 'to', 'at', 'did', 'her', 'but', 'she', 'was']
# Palabras eliminadas: ['you']
# Palabras eliminadas: ['to', 'but', 'on', 'can', 'i', 'it', 'after', 'my', 'have']
# Palabras eliminadas: ['you', 'for', 'the', 'for']
# Palabras eliminadas: ['why', 'you', 'to', 'to']
# Palabras eliminadas: ['a', 'from', 'to', 'and', 'then', 'to', 'is', 'not']
# Palabras eliminadas: ['is', 'with', 'their', 'you', 'can', 'a', 'to']
# Palabras eliminadas: ['then', 'a', 'up', 'by', 'in', 'to', 'with', 'the', 'and']
# Palabras eliminadas: ['why', 'does', 'it', 'to', 'the', 'of', 'when', 'the', 'same', 'on']
# Palabras eliminadas: ['you', 'for', 'a', 'with', 'very', 'and', 'you', 'the', 'what', 'to', 'my']
# Palabras eliminadas: ['do', 'there', 'a', 'for', 'the', 'for', 'of', 'this']
# Palabras eliminadas: ['or', 'is', 'to']
# Palabras eliminadas: ['do', 'you', 'that', 'your', 'does', 'on', 'it', 'a']
# Palabras eliminadas: ['on', 'to', 'no', 'and', 'no', 'more', 'than']
# Palabras eliminadas: ['my', 'i', 'a', 'an', 'to', 'by', 'that', 'those', 'for', 'so', 'too']
# Palabras eliminadas: ['i', 'out', 'for']
# Palabras eliminadas: ['in', 'at', 'was', 'of', 'that', 'having', 'to', 'him', 'to', 'the', 'he', 'was']
# Palabras eliminadas: ['where', 'was', 'the', 'other', 'and', 'this', 'to', 'be', 'from']
# Palabras eliminadas: ['to', 'your', 'i', 'now', 'have', 'a', 'and', 'you', 'to', 'do', 'about', 'it']
# Palabras eliminadas: ['that', 'be', 'you', 'have', 'in', 'your']
# Palabras eliminadas: ['that', 'be', 'after', 'is', 'and', 'i', 'can', 'not', 'through', 'to', 'a', 'or', 'to']
# Palabras eliminadas: ['on', 'for', 'can', 'i', 'a']
# Palabras eliminadas: ['been', 'with', 'my', 'for', 'she', 'from', 'i', 'in', 'me', 'there', 'to', 'my']
# Palabras eliminadas: ['just', 'to', 'their', 'i', 'to', 'them', 'to', 'my']
# Palabras eliminadas: ['for', 'it', 'will', 'be', 'my', 'no', 'to', 'only']
# Palabras eliminadas: []
# Palabras eliminadas: ['you', 'to', 'the', 'i', 'had', 'a', 'and', 'have', 'had', 'to']
# Palabras eliminadas: ['it', 'was', 'so', 'we', 'had', 'to', 'ourselves', 'with']
# Palabras eliminadas: ['do', 'just', 'on', 'to', 'the', 'it', 'was', 'an', 'then', 'have']
# Palabras eliminadas: ['i', 'they', 'had', 'but', 'just', 'out', 'that', 'no', 'i', 'do', 'not', 'have', 'a']
# Palabras eliminadas: ['and', 'what', 'are', 'they', 'your', 'is', 'a']
# Palabras eliminadas: ['you', 'not', 'do', 'a', 'same', 'for', 'me', 'the', 'no']
# Palabras eliminadas: ['you', 'it', 'it', 'on', 'my']
# Palabras eliminadas: ['to', 'to', 'to', 'an', 'have', 'to', 'to']
# Palabras eliminadas: ['i', 'you', 'my', 's', 'you', 'have', 'me', 'what', 'was', 'the', 'of', 'your', 'you', 'did']
# Palabras eliminadas: ['your', 'is']
# Palabras eliminadas: ['at', 'in', 'was', 'so', 'and', 'after', 'what', 'her']
# Palabras eliminadas: ['to', 'on', 'to']
# Palabras eliminadas: ['being', 'and', 'some', 'it', 'should', 'a', 'to', 'you']
# Palabras eliminadas: []
# Palabras eliminadas: ['not', 'i', 'i', 'it', 'off', 'from', 'the', 'for', 'a', 'now']
# Palabras eliminadas: ['so', 'how', 'do', 'we', 'me', 'a']
# Palabras eliminadas: ['you', 'of', 'my', 'up', 'at', 'it', 'was', 'but', 'you', 'did', 'it', 'by', 'me', 'in', 'a']
# Palabras eliminadas: ['and', 'both', 'on', 'on', 'all']
# Palabras eliminadas: ['what', 'are', 'the', 'you', 'can', 'me', 'on', 'a', 'with', 'so', 'i', 'can', 'to']
# Palabras eliminadas: ['you', 'for', 'to', 'it', 'to', 'and', 'your', 'and', 'have', 'been']
# Palabras eliminadas: ['have', 'all', 'so', 'me', 'that', 'so', 'i', 'can', 'a', 'from', 'the']
# Palabras eliminadas: ['but', 'has']
# Palabras eliminadas: ['a', 'few', 'were', 'on', 'you', 'can', 'do', 'for', 'on', 'a']
# Palabras eliminadas: ['that', 'can', 'be', 'a', 'over', 'before', 'you', 'are', 'an']
# Palabras eliminadas: ['my', 'has', 'been', 'in', 'can', 'me', 'with', 'this']
# Palabras eliminadas: ['at', 'to', 'a', 'for', 'just', 'for', 'the', 'each', 'for']
# Palabras eliminadas: ['how', 'on', 'i', 'a', 'at', 'i', 'from', 'and', 'i', 'do', 'have', 'a', 'just']
# Palabras eliminadas: ['it', 'was', 'an', 'and', 'we', 'did', 'our', 'until', 'we', 'were', 'in', 'the']
# Palabras eliminadas: ['been', 'on', 'to', 'can']
# Palabras eliminadas: ['you', 'my', 'to', 'to', 'is', 'on', 'to', 'both']
# Palabras eliminadas: ['did', 'them', 'but', 'he', 'was', 'very', 'and', 'down', 'my', 'they', 'do']
# Palabras eliminadas: ['our', 'on']
# Palabras eliminadas: ['i', 'do', 'that', 'this', 'is', 'down', 'the', 'i']
# Palabras eliminadas: ['so', 'i', 'can', 'before', 'but', 'the']
# Palabras eliminadas: ['why', 'is', 'out', 'to', 'same']
# Palabras eliminadas: ['who', 'is', 'your', 'for', 'with', 'in']
# Palabras eliminadas: ['once', 'again', 'your', 'in', 'was', 'is', 'but', 'no']
# Palabras eliminadas: ['i', 'your', 'i', 'been', 'on', 'all', 'to', 'out', 'why', 'you', 'my']
# Palabras eliminadas: ['it', 'was', 'but', 'it', 'was', 'as', 'there', 'is', 'there', 'when', 'i', 'to', 'with', 'it']
# Palabras eliminadas: ['i', 'just', 'you']
# Palabras eliminadas: []
# Palabras eliminadas: ['for', 'my', 'of', 'the', 'but', 'what', 'does', 'that']
# Palabras eliminadas: ['at', 'which', 'in', 'they', 'have', 'my', 'because', 'i', 'was']
# Palabras eliminadas: ['i', 'i', 'have', 'to', 'the']
# Palabras eliminadas: ['me', 'too']
# Palabras eliminadas: ['for', 'the', 'to', 'my']
# Palabras eliminadas: ['if', 'there', 'was', 'the', 'they', 'not']
# Palabras eliminadas: ['just', 'off', 'your', 'for', 'a', 'on', 'an']
# Palabras eliminadas: ['i', 'you', 'the']
# Palabras eliminadas: ['in', 'a', 'or', 'that', 'is']
# Palabras eliminadas: ['for', 'the']
# Palabras eliminadas: ['you']
# Palabras eliminadas: ['me', 'up', 'with', 'if', 'you', 'have', 'a', 'to', 'the', 'that']
# Palabras eliminadas: ['i', 'that', 'but', 'now', 'i', 'have', 'to', 'more', 'on', 'my', 'the', 'has', 'up', 'over', 'the']
# Palabras eliminadas: ['how', 'are', 'and', 'have', 'and', 'than']
# Palabras eliminadas: ['will', 'you', 'more', 'out', 'of', 'to', 'more', 'of', 'just', 'and']
# Palabras eliminadas: ['you', 'of', 'my', 'and', 'i', 'the', 'to', 'and', 'it', 'in']
# Palabras eliminadas: ['i', 'did', 'should', 'i', 'a', 'in', 'this', 'this']
# Palabras eliminadas: ['is', 'on', 'we', 'have', 'for', 'a', 'we', 'are', 'on', 'a', 'why', 'the']
# Palabras eliminadas: ['the', 'you', 'for', 'to', 'is', 'you', 'should', 'be']
# Palabras eliminadas: ['her', 'is', 'we', 'having', 'an', 'for', 'her']
# Palabras eliminadas: ['the', 'our', 'in', 'the', 'that', 'a', 'so', 'they', 'the', 'out', 'of']
# Palabras eliminadas: ['i', 'have', 'a', 'on', 'the', 'to', 'from', 'i', 'just', 'a', 'on', 'my', 'is', 'the']
# Palabras eliminadas: ['no', 'they', 'too', 'being', 'and', 'to', 'out', 'i']
# Palabras eliminadas: ['the', 'of', 'just', 'this', 'he', 'was', 'into', 'a', 'of']
# Palabras eliminadas: ['not', 'only', 'was', 'it', 'but', 'you', 'my', 'the', 'after', 'for', 'more']
# Palabras eliminadas: ['i', 'be', 'the', 'who', 'herself']
# Palabras eliminadas: ['and', 'it', 'for', 'and']
# Palabras eliminadas: ['you', 'our', 'by', 'to', 'for', 'from', 'that', 'was']
# Palabras eliminadas: ['for', 'the', 'up', 'about', 'the']
# Palabras eliminadas: ['your', 'at', 'are', 'the', 'we', 'we']
# Palabras eliminadas: ['to', 'my', 'of', 'and', 'as', 'as', 'to']
# Palabras eliminadas: ['again']
# Palabras eliminadas: ['why', 'is', 'the', 'so']
# Palabras eliminadas: ['i']
# Palabras eliminadas: ['what', 'a', 'of', 'to']
# Palabras eliminadas: ['i', 'for', 'to', 'my', 'for', 'my', 'and', 'for', 'the', 'that', 'i', 'had', 'to']
# Palabras eliminadas: ['did', 'not', 'over']
# Palabras eliminadas: ['on', 'a', 'can', 'you', 'so', 'that', 'i', 'can']
# Palabras eliminadas: ['it', 'and', 'does', 'have', 'her', 'which', 'was', 'by', 'and', 'to', 'be', 'on', 'its']
# Palabras eliminadas: ['just', 'with', 'the', 'and', 'to', 'on', 'a', 'more', 'not', 'so']
# Palabras eliminadas: ['at', 'the', 'to', 'this']
# Palabras eliminadas: ['up', 'for', 'and', 'then', 'and', 'it', 'did', 'and', 'did', 'the', 'that', 'was', 'for']
# Palabras eliminadas: ['your', 'me', 'in', 'for']
# Palabras eliminadas: ['do', 'you', 'have', 'a', 'for']
# Palabras eliminadas: ['that', 'has', 'to', 'be', 'at', 'the', 'if', 'so', 'what', 'does']
# Palabras eliminadas: ['i', 'she', 'was', 'having', 'a', 'a', 'from', 'an']
# Palabras eliminadas: ['i', 'have', 'and', 'no', 'has', 'been', 'to', 'me', 'out']
# Palabras eliminadas: ['now', 'you', 'have', 'over', 'in', 'this', 'is', 'what', 'the']
# Palabras eliminadas: ['no']
# Palabras eliminadas: ['you', 'for', 'the']
# Palabras eliminadas: ['for', 'the', 'it', 'again', 'we', 'will']
# Palabras eliminadas: ['i', 'to', 'to', 'a', 'being', 'this', 'is', 'not', 'an']
# Palabras eliminadas: ['so', 'i', 'am', 'just', 'to', 'at', 'and', 'then', 'i', 'am', 'to']
# Palabras eliminadas: ['again', 'it', 'the', 'the', 'to']
# Palabras eliminadas: []
# Palabras eliminadas: ['you', 'for', 'your']
# Palabras eliminadas: ['this', 'is', 'why', 'be', 'from', 'to', 'only', 'i']
# Palabras eliminadas: ['can', 'i', 'with']
# Palabras eliminadas: ['are', 'these', 'will', 'not', 'you']
# Palabras eliminadas: ['just', 'to', 'from', 'you', 'have']
# Palabras eliminadas: ['i', 'just', 'for', 'the', 'to']
# Palabras eliminadas: ['you']
# Palabras eliminadas: ['on', 'the', 'of', 'our', 'on']
# Palabras eliminadas: ['for']
# Palabras eliminadas: ['i', 'had']
# Palabras eliminadas: ['how', 'does', 'the']
# Palabras eliminadas: ['not', 'of', 'them', 'can', 'on', 'now', 'it']
# Palabras eliminadas: ['no', 'you', 'that', 'why', 'their', 'is', 'by']
# Palabras eliminadas: ['she', 'to', 'there', 'has', 'been', 'so', 'this', 'this', 'that', 'she', 'she']
# Palabras eliminadas: ['how', 'can', 'i', 'and', 'not', 'have', 'to']
# Palabras eliminadas: ['we', 'to', 'if', 'you']
# Palabras eliminadas: ['to', 'who']
# Palabras eliminadas: ['on', 'the', 'here', 'is', 'to', 'a', 'i', 'not', 'a', 'but']
# Palabras eliminadas: ['of', 'no']
# Palabras eliminadas: ['after', 'no', 'my']
# Palabras eliminadas: ['from', 'being', 'on', 'for', 'over', 'and', 'having', 'to', 'and', 'the', 'not']
# Palabras eliminadas: ['i', 'to']
# Palabras eliminadas: ['some', 'are']
# Palabras eliminadas: ['i', 'from', 'to', 'no', 'on', 'my', 'what', 'the']
# Palabras eliminadas: ['on', 'why', 'not', 're', 'all', 'again']
# Palabras eliminadas: ['this', 'is', 'the', 'i', 'have', 'had', 'to', 'but', 'on', 'me']
# Palabras eliminadas: ['this', 'is', 'it', 'i', 'you', 'up', 'now', 'will', 'be', 'in', 'and']
# Palabras eliminadas: ['just', 'and', 'will', 'be', 'on', 'my']
# Palabras eliminadas: ['why', 'are', 'there', 'so', 'to']
# Palabras eliminadas: ['having', 'some', 'in', 'can', 'you', 'me', 'so', 'i', 'can', 'you']
# Palabras eliminadas: ['i', 'those', 'are', 'am', 'does', 'to', 'my', 'again']
# Palabras eliminadas: ['did', 'have', 'it', 'was', 'to', 'by', 'your']
# Palabras eliminadas: ['will', 'do', 'if', 'you', 'i', 'can', 'that']
# Palabras eliminadas: ['this', 'is', 'to', 'by', 'of']
# Palabras eliminadas: ['i', 'have', 'in', 'in', 'only', 'i', 'have', 'that']
# Palabras eliminadas: ['to', 'in', 'for', 'on', 'not', 'too', 'to', 'my']
# Palabras eliminadas: ['that', 'a', 'there']
# Palabras eliminadas: []
# Palabras eliminadas: ['in', 'the', 'on', 'the', 'at', 'on']
# Palabras eliminadas: ['we', 'you', 'now', 'we', 'can', 'about', 'it', 'and', 'the', 'in', 'will', 'you']
# Palabras eliminadas: ['you', 'me', 'to', 'then', 'them', 'in', 'to', 'to']
# Palabras eliminadas: ['just', 'you', 'on', 'the', 'they', 'on', 'at', 'and', 'off']
# Palabras eliminadas: ['are', 'we', 'to', 'as']
# Palabras eliminadas: ['you', 'to', 'me']
# Palabras eliminadas: ['this', 'does', 'my', 'i', 'am', 'on', 'for', 'to', 'with', 'an']
# Palabras eliminadas: ['when', 'will', 'the', 'of', 'be']
# Palabras eliminadas: ['for', 'a', 'in', 'no']
# Palabras eliminadas: ['your', 'is', 'you', 'have', 'and', 'on', 'the', 'i', 'this']
# Palabras eliminadas: ['which', 'i', 'to', 'in', 'the', 'i', 'to']
# Palabras eliminadas: ['it', 'out', 'have', 'had', 'in', 'the', 'now', 'and', 'that', 'just']
# Palabras eliminadas: ['how', 'the', 'was', 'for', 'from', 'were', 'on', 'in', 'no']
# Palabras eliminadas: ['you', 'for', 'my']
# Palabras eliminadas: ['is', 'doing', 'the', 'they', 'can', 'that', 'is', 'into', 'a']
# Palabras eliminadas: ['how', 'can', 'we', 'with', 'a', 'we', 'with', 'you', 'and', 'are', 'having', 'with']
# Palabras eliminadas: ['to', 'to', 'in']
# Palabras eliminadas: ['that', 'will', 'in', 'the', 'there', 'have', 'been', 'a', 'if', 'i', 'had', 'the']
# Palabras eliminadas: ['i', 'your']
# Palabras eliminadas: ['you']
# Palabras eliminadas: ['an', 'to', 'in', 'is', 'this', 'from', 'just', 'the']
# Palabras eliminadas: ['you', 'for', 'of', 'me', 'with', 'a', 'my', 'was']
# Palabras eliminadas: ['of', 'on', 'to', 'to']
# Palabras eliminadas: ['will', 'do', 'been', 'on', 'now', 'for', 'and', 'now', 'we', 'have', 'to', 'i', 'this', 'up']
# Palabras eliminadas: ['each', 'the', 'other', 'has', 'my', 'on', 'with', 'up']
# Palabras eliminadas: ['i', 'after', 'the', 'on', 'your']
# Palabras eliminadas: ['for', 'your', 'you']
# Palabras eliminadas: ['on', 'and', 'i', 'for', 'that', 'a', 'for', 'your', 'own']
# Palabras eliminadas: ['this']
# Palabras eliminadas: ['i', 'for', 'to', 'to', 'at']
# Palabras eliminadas: ['can', 'you', 'me', 'me', 'to', 'the', 'for', 'a']
# Palabras eliminadas: ['i', 'been', 'your', 'all', 'to', 'my', 'for', 'an', 'but', 'am', 'not', 'to', 'through']
# Palabras eliminadas: ['you', 'to', 'be', 'with', 'you']
# Palabras eliminadas: ['on']
# Palabras eliminadas: ['your', 'has', 'now', 'my', 'to', 'only', 'a', 'but', 'it', 'so', 'is', 'that']
# Palabras eliminadas: ['on', 'the', 'in', 'to', 'off', 'are', 'is', 'up', 'we', 'are', 'but', 'they', 'be']
# Palabras eliminadas: ['can', 'i', 'on', 'i', 'i', 'only', 'when', 'to']
# Palabras eliminadas: ['is', 'it', 'only', 'for', 'my', 'too']
# Palabras eliminadas: ['so', 'to', 'your']
# Palabras eliminadas: ['it', 'for', 'me', 'i', 'with', 'a', 'on', 'the', 'who', 'i', 'a', 'on', 'your', 'i', 'did', 'a', 'few']
# Palabras eliminadas: ['can', 'you', 'my', 'in', 'at', 'from', 'to']
# Palabras eliminadas: ['had', 'to', 'to', 'out', 'i', 'was', 'why', 'for', 'my', 'an', 'for', 'of']
# Palabras eliminadas: ['i', 'now', 'and', 'this', 'how', 'should', 'i', 'have', 'to', 'in']
# Palabras eliminadas: ['you', 'my', 'to', 'when', 'are', 'out', 'just', 'no', 'no']
# Palabras eliminadas: ['i', 'you', 'to', 'other', 'so', 'i', 'can', 'you', 'to', 'my', 'each']
# Palabras eliminadas: ['been', 'all', 'up', 'and', 'down', 'the', 'where', 'the', 'was', 'and', 'do', 'any']
# Palabras eliminadas: ['has', 'and', 'but', 'no', 'i', 'do', 'it', 'how', 'can', 'i']
# Palabras eliminadas: ['for', 'a', 'not', 'a', 'i', 'did', 'not', 'to', 'in', 'the']
# Palabras eliminadas: ['you', 'but', 'the', 'in', 'only', 'me', 'a', 'through', 'and', 'i', 'to']
# Palabras eliminadas: ['me', 'to', 'i', 'do']
# Palabras eliminadas: ['was', 'it', 'was', 'a', 'to', 'this', 'am', 'now', 'your', 'is', 'too', 'to', 'any', 'this', 'am']
# Palabras eliminadas: ['my', 'to', 'both', 'my', 'me', 'from', 'to']
# Palabras eliminadas: ['was', 'for', 'i', 'on', 'now', 'did', 'a', 'just', 'and', 'to']
# Palabras eliminadas: ['you', 'to', 'and', 'they', 'we', 'because', 'this']
# Palabras eliminadas: ['you', 'as', 'as']
# Palabras eliminadas: ['was', 'over', 'an', 'to', 'and', 'now', 'we', 'have', 'no', 'not', 'in', 'a', 'at']
# Palabras eliminadas: ['is', 'there', 'any', 'i', 'can', 'for', 'the', 'i', 'my', 'to', 'the', 'but', 'i', 'to']
# Palabras eliminadas: ['again']
# Palabras eliminadas: ['are', 'being', 'into']
# Palabras eliminadas: ['on', 'same', 'for', 'no', 'no', 'am']
# Palabras eliminadas: ['in', 'and', 'and', 'to']
# Palabras eliminadas: ['i', 'that', 'there', 'are', 'for', 'and', 'in', 'this', 'some', 'should', 'of', 'this']
# Palabras eliminadas: ['can', 'you', 'me', 'where', 'my', 'is', 'i', 'was', 'on', 'to', 'and', 'my', 'to', 'was', 'so', 'to']
# Palabras eliminadas: ['i', 'but', 'the', 'this', 'before', 'we', 'all', 'in', 'the', 'for']
# Palabras eliminadas: ['your', 'or', 'you', 'with', 'at', 'is', 'you']
# Palabras eliminadas: ['what', 'you']
# Palabras eliminadas: ['not', 'off', 'in', 'the', 'of', 'the']
# Palabras eliminadas: ['for', 'they', 'a', 'into', 'a', 'for', 'the']
# Palabras eliminadas: ['i']
# Palabras eliminadas: ['not', 'at', 'the', 'until', 'we', 'all', 'to', 'we', 'are']
# Palabras eliminadas: ['just', 'with', 'you', 'i', 'you', 'my', 'now']
# Palabras eliminadas: ['these', 'are']
# Palabras eliminadas: ['you']
# Palabras eliminadas: ['can', 'you', 'me', 'what', 'that', 'i', 'and', 'just', 'an', 'of', 'i', 'my', 'for']
# Palabras eliminadas: ['this', 'is', 'now', 'that', 'so', 'we', 'can', 'to']
# Palabras eliminadas: ['i', 'have', 'been', 'by', 'a', 'as', 'as', 'i', 'have', 'this', 'by']
# Palabras eliminadas: ['not', 'it']
# Palabras eliminadas: ['the', 'are', 'on', 'the', 'just', 'as', 'a', 'on', 'where', 'is', 'the', 'what', 'do', 'you', 'to']
# Palabras eliminadas: ['was', 'into', 'it', 'to', 'is', 'for', 'in']
# Palabras eliminadas: ['this', 'his', 'off', 'at', 'the', 'and', 'other', 'his', 'so']
# Palabras eliminadas: []
# Palabras eliminadas: ['this', 'is', 'to', 'be', 'the', 'i', 'with', 'an']
# Palabras eliminadas: ['i', 'had', 'to', 'to', 'once', 'again', 'on', 'an', 'i', 'do', 'when', 'to', 'me', 'to']
# Palabras eliminadas: ['to', 'in', 'for', 'a', 'and', 'on', 'all']
# Palabras eliminadas: ['on', 'to']
# Palabras eliminadas: ['our', 'on']
# Palabras eliminadas: ['what', 'with', 'the', 'about', 'to', 'a', 'the', 'the', 'from', 'to']
# Palabras eliminadas: ['is', 'the', 'of', 'do', 'that', 'is', 'do']
# Palabras eliminadas: ['here', 'for', 'a']
# Palabras eliminadas: ['and', 'a', 'on', 'it', 'to', 'be', 'a', 'of', 'too', 'for', 'you']
# Palabras eliminadas: ['the', 'does', 'to', 'be', 'just', 'the']
# Palabras eliminadas: []
# Palabras eliminadas: ['in', 'the']
# Palabras eliminadas: ['have', 'a', 'out', 'of', 'are', 'we', 'to', 'to', 'an']
# Palabras eliminadas: ['to', 'we', 'through', 'we', 'to', 'to']
# Palabras eliminadas: ['has', 'from', 'to']
# Palabras eliminadas: ['an', 'now', 'on', 'the', 'for', 'at', 'the', 'the']
# Palabras eliminadas: ['why', 'does', 'a', 'for', 'what', 'is', 'the', 'that', 'this']
# Palabras eliminadas: ['had', 'to', 'to', 'a', 'very', 'over', 'to', 'about', 'my', 'that', 'my', 'was', 'not', 'a']
# Palabras eliminadas: ['i', 'to', 'them', 'at', 'this']
# Palabras eliminadas: ['to', 'being', 'on', 'had', 'a', 'up', 'to']
# Palabras eliminadas: ['when', 'are', 'you', 'to']
# Palabras eliminadas: ['you', 'but', 'there', 'is', 'on', 'and', 'no', 'on', 'your', 'have']
# Palabras eliminadas: ['this', 'be', 'an']
# Palabras eliminadas: ['will', 'the', 'to', 'me', 'at', 'the']
# Palabras eliminadas: ['here', 'a', 'both', 'and', 'in', 'during']
# Palabras eliminadas: ['i', 'is', 'to', 'its', 'their', 'it', 'is', 'but', 'they', 'it', 'a']
# Palabras eliminadas: ['not', 'to', 'in', 'the', 'now']
# Palabras eliminadas: ['have', 'been', 'if', 'the', 'were', 'at', 'the', 'very', 'the', 'was']
# Palabras eliminadas: ['just', 'me', 'they', 'have', 'an', 'than', 'my', 'to', 'me', 'to']
# Palabras eliminadas: ['i', 'he', 'is']
# Palabras eliminadas: ['to', 'through', 'by', 'to', 'that', 'from', 'a', 'can', 'be', 'in', 'the', 'can']
# Palabras eliminadas: ['after', 'at', 'to', 'to']
# Palabras eliminadas: ['i', 'had', 'on', 'from', 'to']
# ...
# Palabras eliminadas: ['that', 'were', 'up', 'the']
# Palabras eliminadas: ['your', 'into', 'my', 'and', 'my', 'was', 'in', 'a']
# Palabras eliminadas: ['my', 'is', 'now', 'my', 'has', 'to', 'for', 'me', 'at', 'the', 'for', 'on', 'her']
# Palabras eliminadas: ['my', 'was', 'and', 'my', 'to', 'my', 'and', 'i', 'a', 'from']
# Palabras eliminadas: ['the', 'the', 'me', 'does', 'what', 'is', 'your']
# Palabras eliminadas: ['out', 'to', 'the', 'on', 'to', 'the', 'they', 'my', 'the']
# Palabras eliminadas: ['with', 'no', 'from', 'or', 'you', 'it', 'my', 'at', 'no']
# Palabras eliminadas: ['to', 'from', 'to', 'on']
# Palabras eliminadas: ['you']
# Palabras eliminadas: ['you', 'you', 'the', 'too', 'there', 'are', 'no', 'but']
# Palabras eliminadas: ['was', 'by', 'not', 'it', 'was', 'by']
# Palabras eliminadas: ['you', 'are', 'most', 'it', 'as', 'if', 'you', 'that', 'why', 'you']
# Palabras eliminadas: ['with', 'was', 'very', 'you', 'for', 'in', 'a']
# Palabras eliminadas: ['on']
# Palabras eliminadas: ['i', 'my', 'and', 'i', 'to', 'me', 'here']
# Palabras eliminadas: ['my', 'has', 'been', 'who', 'can', 'my']
# Palabras eliminadas: ['from', 'to', 'this', 'did', 'a']
# Palabras eliminadas: ['i', 'been', 'on', 'for', 'now', 'to', 'to', 'with', 'a', 'to', 'my', 'is', 'this']
# Palabras eliminadas: ['you', 'me', 'up', 'but', 'i', 'you', 'a', 'i', 'just', 'a', 'an', 'them', 'to', 'him']
# Palabras eliminadas: ['in', 'of', 'by', 'and', 'you', 'have']
# Palabras eliminadas: ['i', 'i', 'to', 'my']
# Palabras eliminadas: ['at', 'what', 'do', 'to', 'other', 'have']
# Palabras eliminadas: ['is', 'to', 'on', 'the']
# Palabras eliminadas: ['when', 'are', 'the', 'into', 'the', 'but', 'off', 'or', 'with']
# Palabras eliminadas: ['i', 'that', 'the', 'will', 'with', 'the']
# Palabras eliminadas: ['no', 'no', 'you', 'the', 'i', 'did', 'the', 'the', 'me']
# Palabras eliminadas: ['i', 'my', 'off', 'for', 'the', 'i', 'some', 'by', 'the', 'i', 'you', 'have']
# Palabras eliminadas: ['she', 'did', 'she', 'on', 'a', 'the', 'of', 'through', 'is', 'what']
# Palabras eliminadas: []
# Palabras eliminadas: ['from', 'to', 'and', 'a']
# Palabras eliminadas: ['it', 'was', 'from', 'my', 'that', 'in', 'the']
# Palabras eliminadas: ['to', 'to', 'in', 'now']
# Palabras eliminadas: ['will', 'you', 'out', 'a', 'with', 'to', 'there']
# Palabras eliminadas: ['we', 'are', 'no']
# Palabras eliminadas: ['and', 'so', 'for', 'the']
# Palabras eliminadas: ['to', 'and']
# Palabras eliminadas: ['the', 'was', 'to', 'not', 'as']
# Palabras eliminadas: []
# Palabras eliminadas: ['you', 'i', 'it', 'a', 'for', 'you', 'but', 'any', 'be']
# Palabras eliminadas: ['just', 'my', 'was', 'for', 'my', 'how', 'do', 'i', 'my']
# Palabras eliminadas: ['i', 'not', 'i', 'or', 'and', 'i', 'just', 'too', 'to', 'be']
# Palabras eliminadas: ['why']
# Palabras eliminadas: ['any', 'of']
# Palabras eliminadas: ['i', 'the', 'and', 'i', 'was', 'i', 'on', 'for', 'over', 'a', 'to', 'and', 'then', 'off']
# Palabras eliminadas: ['how', 'do', 'you', 'it', 'will', 'to', 'up', 'of', 'your']
# Palabras eliminadas: ['me', 'i', 'am', 'in', 'it', 'is', 'so']
# Palabras eliminadas: ['after', 'we', 'a', 'to', 'the', 'on', 'you', 'our']
# Palabras eliminadas: ['is', 'by', 'a', 'very', 'and', 'during', 'a', 'very', 'you']
# Palabras eliminadas: ['this', 'is', 'not', 'what', 'your', 'to', 'is', 'to', 'now']
# Palabras eliminadas: ['with', 'no', 'you']
# Palabras eliminadas: ['now', 'you', 'my', 'a', 'and', 'now', 'this', 'you', 'are']
# Palabras eliminadas: ['my', 'was', 'but', 'i', 'my', 'on', 'the', 'or', 'the']
# Palabras eliminadas: ['and', 'up', 'on', 'me']
# Palabras eliminadas: ['i', 'the', 'was', 'not', 'to', 'but', 'a', 'to', 'the', 'to', 'them', 'was', 'an']
# Palabras eliminadas: ['for', 'the', 'that', 'was', 'than', 'a', 'for', 'the', 'from', 'the']
# Palabras eliminadas: ['you', 'my', 'it', 'to', 'me', 'until', 'if', 'the', 'is']
# Palabras eliminadas: ['it', 'was', 'a', 'that', 'they', 'were', 'same', 'for', 'and']
# Palabras eliminadas: ['about', 'to', 'to', 'of', 'each']
# Palabras eliminadas: ['so', 'to', 'be']
# Palabras eliminadas: ['his', 'is', 'he', 'has', 'a', 'and', 'is', 'to', 'his', 'this', 'only', 'about']
# Palabras eliminadas: ['i', 'that', 'and', 'they', 'they', 'me', 'and', 'it', 'out', 'of', 'their', 'i', 'an', 'under']
# Palabras eliminadas: ['for', 'the', 'of', 'and', 'the', 'from', 'the']
# Palabras eliminadas: ['can', 'you', 'me', 'so', 'i', 'can', 'the']
# Palabras eliminadas: ['i', 'all', 'these', 'will', 'be', 'in']
# Palabras eliminadas: ['did', 'of', 'the', 'to', 'all', 'there', 'in', 'and']
# Palabras eliminadas: ['i', 'have', 'a', 'in', 'my', 'and', 'i', 'am', 'what', 'should', 'do', 'these', 'i']
# Palabras eliminadas: ['i', 'it', 'have', 'been', 'a', 'for', 'of']
# Palabras eliminadas: ['you', 'do', 'not', 'my']
# Palabras eliminadas: ['their', 'as', 'on', 'to', 'from', 'other', 'to']
# Palabras eliminadas: ['you', 'very', 'we', 'you', 'do', 'it', 'again', 'again', 'in']
# Palabras eliminadas: ['i', 'have', 'with', 'you', 'in', 'the', 'out', 'of', 'have', 'been', 'on', 'my', 'do']
# Palabras eliminadas: ['for', 'you']
# Palabras eliminadas: ['so', 'not', 'be', 'to', 'an', 'the', 'should']
# Palabras eliminadas: []
# Palabras eliminadas: ['me', 'will', 'now', 'me', 'only', 'before', 'my']
# Palabras eliminadas: ['a', 'no', 'for', 'the', 'no', 'no', 'to', 'to']
# Palabras eliminadas: ['how', 'can', 'he', 'again', 'it', 'will', 'be', 'before', 'he']
# Palabras eliminadas: ['why', 'do', 'you', 'to']
# Palabras eliminadas: ['a', 'from', 'to', 'that', 'does', 'have', 'be']
# Palabras eliminadas: ['at', 'the', 'before', 'and', 'your', 'you', 'do', 'have', 'an']
# Palabras eliminadas: ['is', 'with', 'me', 'at', 'a', 'for']
# Palabras eliminadas: ['on', 'to', 'no', 'at']
# Palabras eliminadas: ['at', 'in', 'but', 'at', 'to']
# Palabras eliminadas: ['to', 'from', 'can', 'you', 'up']
# Palabras eliminadas: ['for', 'the', 'to', 'my']
# Palabras eliminadas: ['because', 'your', 'was', 'and', 'they', 'this', 'is', 'to', 'do', 'some']
# Palabras eliminadas: ['just', 'a', 'from', 'for', 'your', 'it', 'no']
# Palabras eliminadas: ['in', 'at', 'over', 'in', 'was', 'only', 'to']
# Palabras eliminadas: ['was', 'in', 'of', 'my', 'other', 'd']
# Palabras eliminadas: ['can', 'you', 'with', 'an']
# Palabras eliminadas: ['to', 'a', 'my']
# Palabras eliminadas: ['i', 'only', 'a', 'few', 'will', 'my']
# Palabras eliminadas: ['the', 'of', 'of', 'the']
# Palabras eliminadas: ['and', 'for', 'to', 'be', 'you', 'should', 'be', 'it', 'in', 'the']
# Palabras eliminadas: ['do', 'you', 'up', 'any', 'more', 'with', 'you', 'again']
# Palabras eliminadas: ['you']
# Palabras eliminadas: ['we', 'what', 'we', 'can', 'do', 'we', 'are', 'most', 'of', 'this', 'is', 'for', 'the']
# Palabras eliminadas: ['so', 'not', 'only', 'were', 'you', 'you', 'my', 'you', 'for', 'a']
# Palabras eliminadas: ['for', 'no', 'too', 'when', 'where', 'does', 'on', 'for', 'so']
# Palabras eliminadas: ['not']
# Palabras eliminadas: ['no']
# Palabras eliminadas: ['on', 'your', 'will', 'be', 'to', 'your', 'when', 'you', 'a']
# Palabras eliminadas: ['my', 'is', 'been', 'i', 'but', 'this', 'is']
# Palabras eliminadas: ['to', 'for', 'on', 'but', 'being', 'not', 'an', 'with', 'how']
# Palabras eliminadas: ['other', 'as', 'for']
# Palabras eliminadas: ['so', 'why', 'is', 'out', 'of', 'for', 'only', 'your']
# Palabras eliminadas: ['will', 'you', 'be', 'an', 'for', 'for', 'this']
# Palabras eliminadas: ['i', 'did', 'her', 'she', 'was', 'not']
# Palabras eliminadas: ['not', 'on', 'my']
# Palabras eliminadas: ['a', 'the', 'it', 'to', 'me', 'up', 'at', 'just', 'to', 'me', 'it', 'again']
# Palabras eliminadas: ['will', 'do', 'the']
# Palabras eliminadas: ['i', 'it', 'there', 'before', 'she', 'so', 'she', 'can', 'have', 'the', 'to', 'have', 'it', 'but', 'the', 'has', 'not']
# Palabras eliminadas: ['you', 'a', 'this', 'and']
# Palabras eliminadas: ['i', 'do', 'that', 'until', 'you', 'me']
# Palabras eliminadas: ['i', 'not', 'you', 'this', 'does']
# Palabras eliminadas: ['now', 'there', 'be', 'on', 'so', 'i', 'can', 'the']
# Palabras eliminadas: ['just', 'you', 'a', 'with', 'the']
# Palabras eliminadas: ['was', 'through', 'have', 'if', 'was']
# Palabras eliminadas: ['i', 'to', 'me', 'out']
# Palabras eliminadas: ['so', 'they', 'did', 'my', 'now', 'i', 'for', 'a', 'this', 'is', 'why', 'you', 'were', 'to', 'on', 'to', 'the']
# Palabras eliminadas: ['is', 'not', 'at', 'because', 'we', 'have', 'to', 'your']
# Palabras eliminadas: ['no', 'at', 'about', 'my', 'was', 'only', 'me', 'now', 'i']
# Palabras eliminadas: ['how', 'about', 'an', 'on']
# Palabras eliminadas: ['have', 'up']
# Palabras eliminadas: ['i', 'will', 'do', 'just', 'about', 'to', 'to', 'the']
# Palabras eliminadas: ['to', 'because', 'of', 'i', 'i', 'i', 'was', 'to', 'out']
# Palabras eliminadas: ['i', 'have', 'no', 'to', 'her', 'while', 'she', 'is', 'in', 'this', 'does', 'not', 'for', 'me', 'her', 'is', 'about', 'to', 'and', 'is', 'to']
# Palabras eliminadas: ['to', 'you', 'to', 'your', 'own', 'over', 'other']
# Palabras eliminadas: ['what', 'when', 'you', 'the', 'of', 'my']
# Palabras eliminadas: ['on']
# Palabras eliminadas: ['all', 'i', 'is', 'an', 'that', 'up', 'on', 'me', 'i', 'a', 'that', 'some', 'will', 'me', 'in']
# Palabras eliminadas: ['on', 'for']
# Palabras eliminadas: ['how', 'do', 'we', 'that']
# Palabras eliminadas: ['the', 'at', 'and', 'no', 'the', 'same']
# Palabras eliminadas: ['has', 'to', 'be', 'the', 'most', 'and', 'that', 'i', 'have']
# Palabras eliminadas: ['you', 'very', 'for', 'the']
# Palabras eliminadas: ['but', 'i', 'had', 'on', 'out', 'no']
# Palabras eliminadas: ['in', 'for', 'of']
# Palabras eliminadas: ['to', 'my', 'is', 'all', 'up', 'had', 'to', 'and', 'a', 'and', 'not', 'out', 'of']
# Palabras eliminadas: ['from']
# Palabras eliminadas: ['i', 'for', 'to', 'with', 'and', 'with', 'any', 'why']
# Palabras eliminadas: ['and', 'him', 'to', 'the', 'and', 'the', 'were']
# Palabras eliminadas: ['why', 'do', 'i', 'have', 'to', 'the', 'of', 'the', 'i', 'the', 'to', 'then', 'all', 'when', 'a', 'on', 'the']
# Palabras eliminadas: ['it', 'has', 'now', 'been', 'i', 'for', 'my', 'y', 'have', 'i', 'had', 'no']
# Palabras eliminadas: ['at', 'the', 'when', 'i', 'off', 'the']
# Palabras eliminadas: ['for', 'can', 'you', 'into', 'this']
# Palabras eliminadas: ['did', 'had', 'to', 'be', 'for', 'by', 'in', 'the', 'that', 'before']
# Palabras eliminadas: ['any', 'on', 'of', 'for', 'out', 'of', 'this']
# Palabras eliminadas: ['or', 'some', 'of', 'the', 'in', 'the', 'at']
# Palabras eliminadas: ['what', 'is', 'the', 'to', 'to']
# Palabras eliminadas: ['all', 'up', 'to']
# Palabras eliminadas: ['no', 'i', 'do', 'not', 'have', 'them', 'for']
# Palabras eliminadas: ['i', 'at', 'the', 'now', 'and', 'your', 'did', 'how', 'to', 'and', 'me', 'with', 'this', 'very']
# Palabras eliminadas: ['who', 'do', 'i', 'to', 'a', 'and', 'to', 'a', 'for', 'on']
# Palabras eliminadas: ['you', 'me', 'in', 'for', 'me', 'to', 'you', 'a', 'if', 'that', 'is', 'what', 'you']
# Palabras eliminadas: ['i', 'a', 'for', 'my', 'be', 'it', 'is', 'in', 'the']
# Palabras eliminadas: ['and', 'the', 'will', 'you', 'why', 'was', 'that']
# Palabras eliminadas: ['just', 'in', 'an', 'after', 'i', 'should', 'of', 'been', 'here', 'your', 'no', 'is', 'not']
# Palabras eliminadas: ['its', 'that', 'at', 'you', 'have', 'in', 'on', 'a']
# Palabras eliminadas: ['then', 'why', 'do', 'you', 'your', 'is', 'the', 'you', 'again']
# Palabras eliminadas: ['my', 'in', 'at', 'will', 'it', 'be', 'to']
# Palabras eliminadas: ['their']
# Palabras eliminadas: ['not', 'not', 'off', 'the']
# Palabras eliminadas: ['i', 'it', 'up', 'in', 'a', 'in', 'for', 'all', 'the', 'of', 'my']
# Palabras eliminadas: ['we', 'not', 'your', 'just', 'not', 'for', 'over', 'an', 'but', 'as', 'your', 'is']
# Palabras eliminadas: ['of', 'but', 'this', 'is', 'your', 'to', 'be', 'when', 'and', 'are']
# Palabras eliminadas: ['me', 'an', 'of', 'after', 'of']
# Palabras eliminadas: ['for', 'the']
# Palabras eliminadas: ['do', 'them', 'under', 'the', 'with', 'i', 'a', 'and', 'own', 'my', 'own']
# Palabras eliminadas: ['your', 'to']
# Palabras eliminadas: ['do', 'me', 'this', 'is', 'a', 'not', 'a', 'or']
# Palabras eliminadas: ['and', 'do', 'for', 'me', 'having', 'a', 'some', 'other', 'to', 'do', 'you', 'me', 'those', 'with', 'that']
# Palabras eliminadas: ['not']
# Palabras eliminadas: ['i', 'have', 'but', 'when', 'i', 'what', 'up']
# Palabras eliminadas: ['we', 'are', 'off', 'to', 'this', 'is', 'now', 'i', 'how', 'to', 'it', 'and']
# Palabras eliminadas: ['do', 'me', 'to', 'be', 'in']
# Palabras eliminadas: ['on', 'was', 'only', 'to', 'be', 'because', 'we', 'you', 'have', 'of', 'it']
# Palabras eliminadas: ['you', 'have', 'no']
# Palabras eliminadas: ['to', 'which', 'we', 'are', 'to', 'be', 'now', 'but', 'has', 'to']
# Palabras eliminadas: ['to', 'there', 'from']
# Palabras eliminadas: ['a', 'very', 'and', 'did', 'no', 'just', 'me', 'to']
# Palabras eliminadas: ['to', 'from', 'to', 'on']
# Palabras eliminadas: ['you', 'is', 'up', 'to']
# Palabras eliminadas: ['do', 'them', 'for', 'while', 'they', 'to', 'their']
# Palabras eliminadas: ['i', 'to', 'what', 'to', 'do', 'my', 'has', 'been', 'and', 'i', 'to']
# Palabras eliminadas: ['i', 'for']
# Palabras eliminadas: ['a', 'from', 'no']
# Palabras eliminadas: ['had', 'a', 'in', 'with', 'that', 'a', 'of']
# Palabras eliminadas: ['i', 'just', 'a', 'of', 'the']
# Palabras eliminadas: ['with', 'the', 'after', 'my']
# Palabras eliminadas: ['for', 'my', 'from', 'to', 'a', 'by', 'me', 'to', 'my', 'on', 'at', 'the']
# Palabras eliminadas: ['if', 'it', 'for', 'my', 'and', 'i', 'to', 'on', 'an', 'can', 'you']
# Palabras eliminadas: ['been', 'on', 'so', 'to', 'my', 'i', 'had', 'to', 'with', 'of', 'there']
# Palabras eliminadas: ['they', 'will', 'me', 'a', 'my']
# Palabras eliminadas: ['haven', 't', 'before', 'and', 'haven', 't', 'this', 'have', 'just', 'in']
# Palabras eliminadas: ['the', 'of', 'he', 'by', 'being', 'a', 'of']
# Palabras eliminadas: ['to', 'your', 'for', 'with', 'to']
# Palabras eliminadas: ['the', 'you', 'to', 'the', 'our', 'was', 'then', 'then', 'again', 'and']
# Palabras eliminadas: ['but', 'you', 'have', 'that', 'you', 'are', 'and', 'on', 'this']
# Palabras eliminadas: ['for', 'in', 'from', 'to', 'was', 'to', 'a']
# Palabras eliminadas: ['have', 'all']
# Palabras eliminadas: ['for', 'my', 'how', 'is', 'it', 'to', 'for', 'a', 'on', 'it', 'why', 'do', 'to', 'not', 'for']
# Palabras eliminadas: ['so']
# Palabras eliminadas: ['i', 'a', 'and', 'too', 'so', 'the']
# Palabras eliminadas: ['has', 'no', 'or', 'in', 'just', 'a', 'with', 'a', 'on', 'it']
# Palabras eliminadas: ['on', 'the', 'to', 'and', 'on', 'the', 'to', 'this', 'is']
# Palabras eliminadas: ['how', 'do', 'i', 'an', 'of', 'on']
# Palabras eliminadas: ['we', 'to', 'have', 'you', 'with', 'when', 'will', 'this', 'be']
# Palabras eliminadas: ['for', 'me', 'and', 'for', 'me', 'on', 'for', 'an', 'on', 'at']
# Palabras eliminadas: ['for', 'the', 'i', 'have', 'had', 'too', 'and', 'will', 'no', 'be', 'with']
# Palabras eliminadas: ['very', 'so', 'an', 'that', 'a', 'and', 'on', 'my']
# Palabras eliminadas: ['not', 'only', 'did', 'you', 'our', 'from', 'and', 'by', 'you', 'now', 'of', 'our']
# Palabras eliminadas: ['that', 'did']
# Palabras eliminadas: ['the', 'you', 'is', 'ours', 'that', 'just', 'the', 'for', 'a', 'she', 'a', 'for', 'the']
# Palabras eliminadas: ['we', 'are', 'into', 'do', 'you', 'or', 'with', 'the']
# Palabras eliminadas: ['can', 'i', 'through', 'to', 'my', 'i', 'from', 'to', 'and', 'to']
# Palabras eliminadas: ['it', 'i', 'was', 'to', 'be', 'in']
# Palabras eliminadas: ['in']
# Palabras eliminadas: ['to', 'and']
# Palabras eliminadas: ['what', 'the', 'to', 'your', 'off', 'at', 'or', 'to', 'in']
# Palabras eliminadas: ['i', 'the', 'you', 'for', 'the', 'of', 'on', 'your', 'but', 'that', 'i', 'have', 'to', 'you', 'again']
# Palabras eliminadas: ['to', 'for', 'in', 'an', 'me', 'out', 'during', 'the', 'while', 'was', 'down']
# Palabras eliminadas: ['you', 'my', 'during', 'the', 'and', 'me', 'a', 'of', 'from', 'to']
# Palabras eliminadas: ['to', 'it', 'in', 'only', 'and', 'a', 'to', 'the', 'for', 'who', 'their']
# Palabras eliminadas: []
# Palabras eliminadas: ['out', 'to', 'at', 'for', 'of', 'if', 'a']
# Precisión del modelo con multiples técnicas: 77.17%

# %% [markdown]
# ### Punto 5 - Comparación y análisis de resultados
#
# En la celda 5 comparen los resultados obtenidos de los diferentes modelos (random forest) y comenten las ventajas del mejor modelo y las desventajas del modelo con el menor desempeño.

# %%
# Celda 5
def compararModelos(models, data, score):
    better = max(data)
    colores = ['#87CEEB' if value != better else '#6B8E23' for value in data]
    fig, ax = plt.subplots(figsize=(12,5))
    bar = ax.bar(models, data, linewidth=0.8, color=colores, edgecolor="silver")
    ax.set_title("Comparación del desempeño de los modelos")
    ax.set_xlabel("Descripción del modelo")
    ax.set_ylabel(score)
    bar_labels = [f'{value:.3f}' for value in data] 
    ax.bar_label(bar, bar_labels, label_type='center', padding=20)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.set_facecolor("whitesmoke")
    ax.spines["left"].set_color("gray")
    ax.spines["bottom"].set_color("gray")
    ax.tick_params(axis='x', labelsize=8)
    plt.gca().yaxis.set_major_formatter('{:,.5f}'.format)
    plt.tight_layout()
    plt.show()

modelos = ["CountVectorizer",'Eliminación de Stopwords', 'Lematización con verbos' , 'Multiples técnicas']
accuracys = [accuracy,accuracy_2,accuracy_3,accuracy_4]

compararModelos(modelos, accuracys, "Accuracy")

# %% [markdown]
# Las ventajas de la implementación de las estrategias se enuncian a continuación:
# #### Eliminación de stopwords:
#
# ##### Ventajas:
# - A través de la eliminación de stopwords se eliminan palabras muy repetitivas y con poca información  predictiva, como conectores y artículos, por lo que el análisis se limita solo a aquellas palabras con alta mayor información explicativa.
# ##### Desventajas:
# - En algunos contextos existen stopwords que pueden brindar información predictiva para el análisis de texto y la eliminación de las mismas puede hacer que se pierda contexto o significado de frases. Por ejemplo, en este contexto, los tweets tienden a ser cortos, por lo que la eliminación de las stopwords hacen que sean muy pocas las palabras extraídas de cada tweet.
#
# #### Lematización:
#
# ##### Ventajas:
# - Asimismo, a través de la lematización de palabras se transforman los verbos a su estructura de diccionario, lo que hace que todas las distintas formas gramaticales de los verbos se tomen en cuenta como una misma, esto hace que se reduzca la dimensionalidad y facilita la agrupación de palabras relacionadas.
# ##### Desventajas:
# - Al lematizar se pierde la estructura gramatical original de las palabras lematizadas (en este caso los verbos), en casos donde la morfología de las palabras es importante esto puede llevar a perdida de contexto y llevar a predicciones erróneas por parte del algoritmo.
# - El proceso de lematización es más costoso computacionalmente, ya que emplea diccionarios pre cargados en las librerías para generar el homólogo de diccionario de cada verbo, lo que implica una búsqueda exhaustiva de cada verbo en el diccionario. Esto añade un paso adicional a los demás algoritmos y es uno de los más costosos computacionalmente, incluso por encima del stemming.
# En este contexto puntual se considera un buen ejercicio lematizar para reducir la dimensionalidad y el ruido generado por las distintas formas gramaticales de los verbos que no brindan información para la predicción de sentimientos en los tweets.
